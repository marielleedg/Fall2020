# %% [markdown]
# <a href="https://colab.research.google.com/github/dudaspm/Fall2020/blob/master/Introduction%20to%20Web%20Design%20and%20Development/CreatingDigraphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from graphviz import Digraph 
from google.colab import files

HTMLTree = Digraph(format='svg')

HTMLTree.node('HTML') 
HTMLTree.node('head') 
HTMLTree.node('body')

HTMLTree.edge('HTML', 'head') 
HTMLTree.edge('HTML', 'body') 
HTMLTree.render('graph1', view=True) 
files.download("graph1.svg") 
HTMLTree

# %%
from graphviz import Digraph 
from google.colab import files

HTMLTree = Digraph(format='svg')


HTMLTree.edge('html', 'head') 
HTMLTree.edge('html', 'body') 
HTMLTree.edge('head', 'title') 
HTMLTree.edge('body', 'hello') 

HTMLTree.render('graph2', view=True) 
files.download("graph2.svg") 
HTMLTree
